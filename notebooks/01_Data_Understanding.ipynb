# %%
import pandas as pd
import numpy as np

# Display all columns
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../data/air_quality.csv")

df.head()
# Out:
#   country           state               city pollutant_id  pollutant_min  \
# 0   India  Andhra Pradesh             Kadapa        OZONE           39.0
# 1   India  Andhra Pradesh      Machilipatnam          NO2           13.0
# 2   India  Andhra Pradesh      Machilipatnam          NH3            3.0
# 3   India  Andhra Pradesh            Nellore         PM10           45.0
# 4   India  Andhra Pradesh  Rajamahendravaram        PM2.5            5.0
#
#    pollutant_max  pollutant_avg  AQI AQI_Bucket  Temperature_C  Humidity_%  \
# 0           41.0           40.0   20       Good           23.8        68.2
# 1           33.0           18.0   15       Good           30.6        60.3
# 2            5.0            4.0    1       Good           28.4        44.3
# 3          106.0           66.0   96   Moderate           39.6        38.9
# 4           19.0           11.0   12       Good           21.4        47.7
#
#    Wind_Speed_kmh
# 0            10.6
# 1            19.1
# 2             8.8
# 3             2.5
# 4            28.3

# %%
print("Shape:", df.shape)
# Out:
# Shape: (10521, 12)

# %%
print(df.columns.tolist())
# Out:
# ['country', 'state', 'city', 'pollutant_id', 'pollutant_min', 'pollutant_max', 'pollutant_avg', 'AQI', 'AQI_Bucket', 'Temperature_C', 'Humidity_%', 'Wind_Speed_kmh']

# %%
df.dtypes
# Out:
# country               str
# state                 str
# city                  str
# pollutant_id          str
# pollutant_min     float64
# pollutant_max     float64
# pollutant_avg     float64
# AQI                 int64
# AQI_Bucket            str
# Temperature_C     float64
# Humidity_%        float64
# Wind_Speed_kmh    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# country             0
# state               0
# city                0
# pollutant_id        0
# pollutant_min     357
# pollutant_max     357
# pollutant_avg     357
# AQI                 0
# AQI_Bucket          0
# Temperature_C       0
# Humidity_%          0
# Wind_Speed_kmh      0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
for col in df.columns:
    print(f"{col}: {df[col].nunique()}")
# Out:
# country: 1
# state: 30
# city: 268
# pollutant_id: 7
# pollutant_min: 1931
# pollutant_max: 3577
# pollutant_avg: 2476
# AQI: 478
# AQI_Bucket: 6
# Temperature_C: 251
# Humidity_%: 651
# Wind_Speed_kmh: 301

# %%
df = df.drop_duplicates()

print(df.shape)
# Out:
# (10521, 12)

# %%
#Remove Columns with Only One Unique Value
single_value_cols = [
    col for col in df.columns
    if df[col].nunique() == 1
]

print(single_value_cols)

df.drop(columns=single_value_cols, inplace=True)
# Out:
# ['country']

# %%
df.to_csv(
    "../data/air_quality_clean.csv",
    index=False
)

print("Clean dataset saved successfully.")
# Out:
# Clean dataset saved successfully.

# %%
# summary
print("=" * 50)
print("PREPROCESSING SUMMARY")
print("=" * 50)

print(f"Original Shape : (10521, 12)")
print(f"Cleaned Shape  : {df.shape}")



print(f"Duplicate Rows Removed : {df.duplicated().sum()}")

print("\nFinal Columns:")
print(df.columns.tolist())
# Out:
# ==================================================
# PREPROCESSING SUMMARY
# ==================================================
# Original Shape : (10521, 12)
# Cleaned Shape  : (10521, 11)
# Duplicate Rows Removed : 0
#
# Final Columns:
# ['state', 'city', 'pollutant_id', 'pollutant_min', 'pollutant_max', 'pollutant_avg', 'AQI', 'AQI_Bucket', 'Temperature_C', 'Humidity_%', 'Wind_Speed_kmh']
